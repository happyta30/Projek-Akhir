# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # Import Dataset

# %%
df = pd.read_csv('USA_Housing.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address  longitude  latitude
# 0  208 Michael Ferry Apt. 674\r\nLaurabury, NE 37...    -114.31     34.19
# 1  188 Johnson Views Suite 079\r\nLake Kathleen, ...    -114.47     34.40
# 2  9127 Elizabeth Stravenue\r\nDanieltown, WI 064...    -114.56     33.69
# 3                        USS Barnett\r\nFPO AP 44820    -114.57     33.64
# 4                       USNS Raymond\r\nFPO AE 09386    -114.57     33.57

# %% [markdown]
# *   Penjelasan Setiap Kolom
#
#  1. Avg. Area Income = Rata - rata pendapatan penduduk dikota yang sama dengan rumah tersebut
#  2. Avg. Area House Age = Rata - rata usia rumah dikota yang sama
#  3. Avg. Area Number of Rooms = Rata -rata jumlah Kamar dikota yang sama
#  4. Avg. Area Number of Bedrooms = Rata -rata jumlah Kamar tidur dikota yang sama
#  5. Area Population	 = Populasi kota tempat rumah tersebut
#  6. price = Harga dari rumah (US$)
#  7. Address = Alamat rumah

# %% [markdown]
# # Handling Missing Value

# %%
# Melihat jumlah baris pada dataset

df.shape
# Out:
# (5000, 9)

# %%
# Melihat nilai kosong pada dataset

df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# longitude                       0
# latitude                        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
#  7   longitude                     5000 non-null   float64
#  8   latitude                      5000 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 351.7+ KB

# %% [markdown]
# **Dataset tidak memiliki nilai kosong**

# %% [markdown]
# # Statistik Data

# %%
# melihat statistik data

df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price  \
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928702  9.975771e+05
# 50%                        4.050000     36199.406689  1.232669e+06
# 75%                        4.490000     42861.290769  1.471210e+06
# max                        6.500000     69621.713378  2.469066e+06
#
#          longitude     latitude
# count  5000.000000  5000.000000
# mean   -117.482700    33.631748
# std       0.552238     0.555978
# min    -118.110000    32.540000
# 25%    -117.930000    33.150000
# 50%    -117.625000    33.790000
# 75%    -117.140000    34.040000
# max    -114.310000    36.640000

# %%
# Merubah tipe data kolom Rooms, Bedrooms, population dari float menjadi int

df["Avg. Area Number of Rooms"] = df["Avg. Area Number of Rooms"].astype("int") 
df["Avg. Area Number of Bedrooms"] = df["Avg. Area Number of Bedrooms"].astype("int") 
df["Area Population"] = df["Area Population"].astype("int") 
df["Price"] = df["Price"].astype("int")

# %%
# Hasil update dataset

df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.492200
# std        10657.991214             0.991456                   1.048503
# min        17796.631190             2.644304                   3.000000
# 25%        61480.562388             5.322283                   6.000000
# 50%        68804.286404             5.970429                   7.000000
# 75%        75783.338666             6.650808                   7.000000
# max       107701.748378             9.519088                  10.000000
#
#        Avg. Area Number of Bedrooms  Area Population         Price  \
# count                   5000.000000       5000.00000  5.000000e+03
# mean                       3.732400      36163.01500  1.232072e+06
# std                        1.225843       9925.64664  3.531176e+05
# min                        2.000000        172.00000  1.593800e+04
# 25%                        3.000000      29403.75000  9.975765e+05
# 50%                        4.000000      36199.00000  1.232669e+06
# 75%                        4.000000      42861.00000  1.471210e+06
# max                        6.000000      69621.00000  2.469065e+06
#
#          longitude     latitude
# count  5000.000000  5000.000000
# mean   -117.482700    33.631748
# std       0.552238     0.555978
# min    -118.110000    32.540000
# 25%    -117.930000    33.150000
# 50%    -117.625000    33.790000
# 75%    -117.140000    34.040000
# max    -114.310000    36.640000

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address',
#        'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# ## Korelasi Variabel

# %%
plt.figure(figsize=(10,8))
plt.title('Correlation Matrix')
sns.heatmap(df.corr(),annot=True)

# %%
df.corr()["Price"].sort_values(ascending=False)
# Out:
# Price                           1.000000
# Avg. Area Income                0.639734
# Avg. Area House Age             0.452543
# Area Population                 0.408556
# Avg. Area Number of Rooms       0.325114
# Avg. Area Number of Bedrooms    0.172429
# longitude                       0.000484
# latitude                       -0.020564
# Name: Price, dtype: float64

# %% [markdown]
# **Kesimpulan**
#
#
# *   Variabel Avg. Area Income memiliki korelasi yang paling tinggi diantara variabel yang lain
# *  Variabel Address tidak mempengaruhi karena berupa teks

# %% [markdown]
# ## Sebaran Data Variabel Price

# %%
# Melihat sebaran data price

sns.distplot(df['Avg. Area House Age'])

# %% [markdown]
# **Kesimpulan**
#
# *   Sebaran data Avg. Area House Age terdistribusi normal.

# %% [markdown]
# ## Melihat Distribusi Data Tiap Variabel Yang Digunakan

# %%
# Melihat distribusi dari Avg. Area Income

f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['Avg. Area Income'].plot(kind='kde')

f.add_subplot(1,2,2)
plt.boxplot(df['Avg. Area Income'])
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# * Sebagian besar pendapatan berada diangka 75000
# * Data memiliki sedikit outliers

# %%
# Melihat distribusi dari Price

f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['Price'].plot(kind='kde')

f.add_subplot(1,2,2)
plt.boxplot(df['Price'])
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# * sebagian besar harga rumah adalah 1250000 US$
# * Data memiliki sedikit outliers

# %%
# Melihat distribusi dari Area Population
# Data berupa continous/numerik, maka digunakan histogram garis

f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['Area Population'].plot(kind='kde')

f.add_subplot(1,2,2)
plt.boxplot(df['Area Population'])
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# * Sebagian besar populasi berada pada nilai 35000
# * Data memiliki sedikit outliers.

# %%
# Melihat distribusi dari Avg. Area Number of Rooms

f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
sns.countplot(df['Avg. Area Number of Rooms'])

f.add_subplot(1,2,2)
plt.boxplot(df['Avg. Area Number of Rooms'])
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# * Sebagian besar rumah memiliki jumlah kamar 6 dan 7
# * Data memiliki outliers.

# %%
# Melihat distribusi dari Avg. Area Number of Bedrooms

f = plt.figure(figsize=(15,5))

f.add_subplot(1,2,1)
sns.countplot(df['Avg. Area Number of Bedrooms'])

f.add_subplot(1,2,2)
plt.boxplot(df['Avg. Area Number of Bedrooms'])
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# * Sebagian besar rumah memiliki jumlah kamar tidur siap pakai 3 dan 4
# * Data memiliki outliers.

# %% [markdown]
# ## Hubungan antara independent dan dependent variabel

# %%
plt.figure(figsize=(10,8))
sns.pairplot(data=df, x_vars=df.drop(['Avg. Area House Age', 'Address', 'longitude', 'latitude'], axis=1), y_vars=['Avg. Area House Age'], size=5, aspect=0.75)
plt.show()

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # Modelling

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                          7
# 1      79248.642455             6.002900                          6
# 2      61287.067179             5.865890                          8
# 3      63345.240046             7.188236                          5
# 4      59982.197226             5.040555                          7
#
#    Avg. Area Number of Bedrooms  Area Population    Price  \
# 0                             4            23086  1059033
# 1                             3            40173  1505890
# 2                             5            36882  1058987
# 3                             3            34310  1260616
# 4                             4            26354   630943
#
#                                              Address  longitude  latitude
# 0  208 Michael Ferry Apt. 674\r\nLaurabury, NE 37...    -114.31     34.19
# 1  188 Johnson Views Suite 079\r\nLake Kathleen, ...    -114.47     34.40
# 2  9127 Elizabeth Stravenue\r\nDanieltown, WI 064...    -114.56     33.69
# 3                        USS Barnett\r\nFPO AP 44820    -114.57     33.64
# 4                       USNS Raymond\r\nFPO AE 09386    -114.57     33.57

# %%
# Buat variabel x dan y

X = df.drop(['Avg. Area House Age','Address','longitude', 'latitude'], axis=1)
y = df['Avg. Area House Age']
X.head()
# Out:
#    Avg. Area Income  Avg. Area Number of Rooms  Avg. Area Number of Bedrooms  \
# 0      79545.458574                          7                             4
# 1      79248.642455                          6                             3
# 2      61287.067179                          8                             5
# 3      63345.240046                          5                             3
# 4      59982.197226                          7                             4
#
#    Area Population    Price
# 0            23086  1059033
# 1            40173  1505890
# 2            36882  1058987
# 3            34310  1260616
# 4            26354   630943

# %% [markdown]
# ## Split Dataset

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2021)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (4000, 5)
# (4000,)
# (1000, 5)
# (1000,)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(x_train,y_train)

print(f'R² score: {r2_score(y_test, lin_reg.predict(x_test))*100}')
# Out:
# R² score: 70.9848376778935

# %%
# Linear Regression Graph

plt.scatter(y_test,lin_reg.predict(x_test), color="b")
plt.plot(lin_reg.predict(x_test),lin_reg.predict(x_test), color="r")

# %% [markdown]
# ## Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree = 2)
x_poly_train = poly_reg.fit_transform(x_train)
x_poly_test = poly_reg.fit_transform(x_test)

lin_reg2 = LinearRegression()
lin_reg2.fit(x_poly_train,y_train)


print(f'R² score: {r2_score(y_test, lin_reg2.predict(x_poly_test))*100}')
# Out:
# R² score: 70.92352979379413

# %%
# Polynomial Regression Graph

plt.scatter(y_test,lin_reg2.predict(x_poly_test), color="b")
plt.plot(lin_reg2.predict(x_poly_test),lin_reg2.predict(x_poly_test), color="r")

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

r_dt = DecisionTreeRegressor(random_state=0)
r_dt.fit(x_train,y_train)

print(f'R² score: {r2_score(y_test, r_dt.predict(x_test))*100}')
# Out:
# R² score: 29.815969220453155

# %%
# Decision Tree - Regression Graph

plt.scatter(y_test,r_dt.predict(x_test), color="b")
plt.plot(r_dt.predict(x_test),r_dt.predict(x_test), color="r")

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg=RandomForestRegressor(n_estimators = 100,random_state=0)
rf_reg.fit(x_train,y_train)

print(f'R² score: {r2_score(y_test, rf_reg.predict(x_test))*100}')
# Out:
# R² score: 60.57548425255408

# %%
# Random Forest - Regression Graph

plt.scatter(y_test,rf_reg.predict(x_test), color="b")
plt.plot(rf_reg.predict(x_test),rf_reg.predict(x_test), color="r")

# %% [markdown]
# ## Improve Model AKurasi dengan GridSearchCV

# %% [markdown]
# ### Import library xgboost dan transformasikan data dengan algoritma gridsearchcv

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2021)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (4000, 5)
# (4000,)
# (1000, 5)
# (1000,)

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor()

# %%
# setting parameter hyperparameter (dictionary)

search_space = {
    "n_estimators" : [100, 200, 500],
    "max_depth" : [3, 6, 9],
    "gamma" : [0.01, 0.1],
    "learning_rate" : [0.001, 0.01, 0.1, 1]
}

# %%
from sklearn.model_selection import GridSearchCV

GS = GridSearchCV(estimator = xgb_model,
                  param_grid = search_space,
                  scoring = ["r2", "neg_root_mean_squared_error"],
                  refit = "r2",
                  cv = 5,
                  verbose = 4
                  )

# %%
GS.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [14:57:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.079) r2: (test=-24.579) total time=   0.4s
# [14:57:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.076) r2: (test=-25.693) total time=   0.2s
# [14:57:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-4.970) r2: (test=-24.318) total time=   0.3s
# [14:57:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.043) r2: (test=-27.059) total time=   0.2s
# [14:57:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.054) r2: (test=-24.750) total time=   0.2s
# [14:57:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.613) r2: (test=-20.100) total time=   0.5s
# [14:57:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.614) r2: (test=-21.056) total time=   0.5s
# [14:57:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.504) r2: (test=-19.793) total time=   0.5s
# [14:57:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.578) r2: (test=-22.124) total time=   0.5s
# [14:57:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-4.588) r2: (test=-20.222) total time=   0.5s
# [14:57:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-3.472) r2: (test=-10.951) total time=   1.2s
# [14:57:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-3.482) r2: (test=-11.562) total time=   1.1s
# [14:57:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-3.366) r2: (test=-10.616) total time=   1.2s
# [14:57:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-3.439) r2: (test=-12.047) total time=   1.2s
# [14:57:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-3.448) r2: (test=-10.984) total time=   1.7s
# [14:57:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-5.080) r2: (test=-24.585) total time=   0.3s
# [14:57:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-5.075) r2: (test=-25.682) total time=   0.4s
# [14:57:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-4.971) r2: (test=-24.333) total time=   0.4s
# [14:57:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-5.043) r2: (test=-27.059) total time=   0.4s
# [14:57:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-5.054) r2: (test=-24.755) total time=   0.4s
# [14:57:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.613) r2: (test=-20.100) total time=   0.7s
# [14:57:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.611) r2: (test=-21.033) total time=   0.7s
# [14:57:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.506) r2: (test=-19.815) total time=   0.8s
# [14:57:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.579) r2: (test=-22.126) total time=   0.7s
# [14:57:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-4.588) r2: (test=-20.224) total time=   0.8s
# [14:57:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-3.466) r2: (test=-10.909) total time=   1.9s
# [14:57:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-3.475) r2: (test=-11.510) total time=   2.0s
# [14:57:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-3.366) r2: (test=-10.618) total time=   1.2s
# [14:57:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-3.436) r2: (test=-12.024) total time=   1.2s
# [14:57:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-3.444) r2: (test=-10.956) total time=   1.2s
# [14:57:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.080) r2: (test=-24.585) total time=   0.2s
# [14:57:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.075) r2: (test=-25.682) total time=   0.2s
# [14:57:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-4.971) r2: (test=-24.333) total time=   0.2s
# [14:57:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.043) r2: (test=-27.059) total time=   0.2s
# [14:57:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-5.054) r2: (test=-24.755) total time=   0.3s
# [14:57:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-4.613) r2: (test=-20.099) total time=   0.4s
# [14:57:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-4.611) r2: (test=-21.033) total time=   0.4s
# [14:57:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-4.506) r2: (test=-19.815) total time=   0.5s
# [14:57:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-4.579) r2: (test=-22.126) total time=   0.5s
# [14:57:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-4.588) r2: (test=-20.224) total time=   0.5s
# [14:57:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-3.466) r2: (test=-10.912) total time=   1.3s
# [14:57:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-3.475) r2: (test=-11.512) total time=   1.3s
# [14:57:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-3.367) r2: (test=-10.620) total time=   1.3s
# [14:57:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-3.437) r2: (test=-12.027) total time=   1.3s
# [14:57:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-3.444) r2: (test=-10.954) total time=   1.3s
# [14:57:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-2.209) r2: (test=-3.838) total time=   0.1s
# [14:57:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-2.225) r2: (test=-4.128) total time=   0.1s
# [14:57:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-2.112) r2: (test=-3.574) total time=   0.1s
# [14:57:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-2.173) r2: (test=-4.211) total time=   0.1s
# [14:57:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-2.186) r2: (test=-3.819) total time=   0.1s
# [14:57:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1.101) r2: (test=-0.201) total time=   0.3s
# [14:57:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1.114) r2: (test=-0.286) total time=   0.3s
# [14:57:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1.041) r2: (test=-0.111) total time=   0.3s
# [14:57:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1.061) r2: (test=-0.242) total time=   0.3s
# [14:57:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1.093) r2: (test=-0.205) total time=   0.3s
# [14:57:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.698) r2: (test=0.518) total time=   0.7s
# [14:57:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.695) r2: (test=0.499) total time=   0.7s
# [14:57:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.715) r2: (test=0.476) total time=   0.7s
# [14:57:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.672) r2: (test=0.502) total time=   0.7s
# [14:57:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.713) r2: (test=0.487) total time=   0.7s
# [14:57:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-2.187) r2: (test=-3.743) total time=   0.3s
# [14:57:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-2.202) r2: (test=-4.025) total time=   0.3s
# [14:57:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-2.099) r2: (test=-3.516) total time=   0.3s
# [14:57:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-2.159) r2: (test=-4.140) total time=   0.3s
# [14:57:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-2.167) r2: (test=-3.733) total time=   0.3s
# [14:57:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1.029) r2: (test=-0.049) total time=   0.5s
# [14:57:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1.041) r2: (test=-0.123) total time=   0.5s
# [14:57:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.970) r2: (test=0.035) total time=   0.5s
# [14:57:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.999) r2: (test=-0.100) total time=   0.5s
# [14:57:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1.013) r2: (test=-0.035) total time=   0.5s
# [14:57:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.607) r2: (test=0.635) total time=   1.3s
# [14:57:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.596) r2: (test=0.632) total time=   1.3s
# [14:57:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.616) r2: (test=0.611) total time=   1.3s
# [14:57:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.590) r2: (test=0.615) total time=   1.3s
# [14:57:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.615) r2: (test=0.619) total time=   1.3s
# [14:57:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-2.187) r2: (test=-3.743) total time=   0.3s
# [14:57:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-2.202) r2: (test=-4.024) total time=   0.3s
# [14:57:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-2.100) r2: (test=-3.519) total time=   0.3s
# [14:57:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-2.160) r2: (test=-4.147) total time=   0.3s
# [14:57:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-2.166) r2: (test=-3.731) total time=   0.3s
# [14:57:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1.025) r2: (test=-0.041) total time=   0.7s
# [14:57:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1.039) r2: (test=-0.119) total time=   0.8s
# [14:58:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.968) r2: (test=0.039) total time=   0.7s
# [14:58:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.997) r2: (test=-0.097) total time=   0.7s
# [14:58:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1.011) r2: (test=-0.030) total time=   0.7s
# [14:58:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.615) r2: (test=0.626) total time=   2.1s
# [14:58:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.602) r2: (test=0.625) total time=   2.0s
# [14:58:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.621) r2: (test=0.605) total time=   2.0s
# [14:58:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.589) r2: (test=0.617) total time=   2.0s
# [14:58:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.627) r2: (test=0.603) total time=   2.0s
# [14:58:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.619) r2: (test=0.621) total time=   0.1s
# [14:58:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.613) r2: (test=0.610) total time=   0.2s
# [14:58:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.644) r2: (test=0.574) total time=   0.1s
# [14:58:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.598) r2: (test=0.606) total time=   0.1s
# [14:58:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.632) r2: (test=0.597) total time=   0.1s
# [14:58:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.583) r2: (test=0.663) total time=   0.3s
# [14:58:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.578) r2: (test=0.653) total time=   0.3s
# [14:58:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.603) r2: (test=0.627) total time=   0.3s
# [14:58:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.566) r2: (test=0.647) total time=   0.3s
# [14:58:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.597) r2: (test=0.640) total time=   0.3s
# [14:58:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.581) r2: (test=0.665) total time=   0.7s
# [14:58:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.578) r2: (test=0.654) total time=   0.7s
# [14:58:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.600) r2: (test=0.631) total time=   0.7s
# [14:58:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.562) r2: (test=0.651) total time=   0.7s
# [14:58:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.596) r2: (test=0.642) total time=   0.7s
# [14:58:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.597) r2: (test=0.646) total time=   0.3s
# [14:58:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.592) r2: (test=0.637) total time=   0.3s
# [14:58:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.609) r2: (test=0.620) total time=   0.3s
# [14:58:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.577) r2: (test=0.632) total time=   0.3s
# [14:58:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.608) r2: (test=0.628) total time=   0.3s
# [14:58:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.603) r2: (test=0.639) total time=   0.5s
# [14:58:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.598) r2: (test=0.630) total time=   0.5s
# [14:58:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.616) r2: (test=0.611) total time=   0.5s
# [14:58:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.577) r2: (test=0.633) total time=   0.5s
# [14:58:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.613) r2: (test=0.621) total time=   0.5s
# [14:58:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.621) r2: (test=0.617) total time=   1.3s
# [14:58:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.607) r2: (test=0.618) total time=   1.3s
# [14:58:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.629) r2: (test=0.594) total time=   1.3s
# [14:58:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.587) r2: (test=0.620) total time=   1.3s
# [14:58:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.625) r2: (test=0.606) total time=   1.3s
# [14:58:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.625) r2: (test=0.613) total time=   0.4s
# [14:58:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.599) r2: (test=0.628) total time=   0.4s
# [14:58:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.630) r2: (test=0.594) total time=   0.4s
# [14:58:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.601) r2: (test=0.602) total time=   0.4s
# [14:58:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.633) r2: (test=0.596) total time=   0.4s
# [14:58:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.632) r2: (test=0.604) total time=   0.8s
# [14:58:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.604) r2: (test=0.622) total time=   0.8s
# [14:58:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.637) r2: (test=0.584) total time=   0.8s
# [14:58:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.603) r2: (test=0.599) total time=   0.8s
# [14:58:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.639) r2: (test=0.588) total time=   0.8s
# [14:58:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.638) r2: (test=0.596) total time=   1.9s
# [14:58:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.607) r2: (test=0.618) total time=   1.8s
# [14:58:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.641) r2: (test=0.579) total time=   1.7s
# [14:58:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.609) r2: (test=0.591) total time=   1.9s
# [14:58:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.643) r2: (test=0.583) total time=   1.8s
# [14:58:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.674) r2: (test=0.550) total time=   0.2s
# [14:58:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.675) r2: (test=0.528) total time=   0.2s
# [14:58:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.666) r2: (test=0.546) total time=   0.2s
# [14:58:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.676) r2: (test=0.495) total time=   0.2s
# [14:58:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.665) r2: (test=0.554) total time=   0.2s
# [14:58:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.709) r2: (test=0.502) total time=   0.3s
# [14:58:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.693) r2: (test=0.502) total time=   0.3s
# [14:58:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.704) r2: (test=0.492) total time=   0.3s
# [14:58:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.706) r2: (test=0.450) total time=   0.3s
# [14:58:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.691) r2: (test=0.518) total time=   0.3s
# [14:58:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.744) r2: (test=0.451) total time=   0.7s
# [14:58:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.701) r2: (test=0.492) total time=   0.7s
# [14:58:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.740) r2: (test=0.439) total time=   0.7s
# [14:58:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.729) r2: (test=0.414) total time=   0.7s
# [14:58:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.715) r2: (test=0.484) total time=   0.7s
# [14:58:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.770) r2: (test=0.412) total time=   0.3s
# [14:58:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.768) r2: (test=0.388) total time=   0.3s
# [14:58:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.791) r2: (test=0.359) total time=   0.3s
# [14:58:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.796) r2: (test=0.301) total time=   0.3s
# [14:58:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.784) r2: (test=0.380) total time=   0.3s
# [14:58:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.768) r2: (test=0.415) total time=   0.5s
# [14:58:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.769) r2: (test=0.387) total time=   0.5s
# [14:58:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.792) r2: (test=0.357) total time=   0.5s
# [14:58:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.796) r2: (test=0.301) total time=   0.5s
# [14:58:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.786) r2: (test=0.378) total time=   0.5s
# [14:58:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.768) r2: (test=0.415) total time=   1.2s
# [14:58:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.769) r2: (test=0.387) total time=   1.2s
# [14:58:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.792) r2: (test=0.357) total time=   1.1s
# [14:58:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.796) r2: (test=0.301) total time=   1.2s
# [14:58:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.786) r2: (test=0.378) total time=   1.1s
# [14:58:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.786) r2: (test=0.388) total time=   0.4s
# [14:58:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.793) r2: (test=0.349) total time=   0.4s
# [14:59:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.793) r2: (test=0.356) total time=   0.4s
# [14:59:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.788) r2: (test=0.315) total time=   0.4s
# [14:59:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.631) r2: (test=0.598) total time=   0.4s
# [15:00:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.620) r2: (test=0.619) total time=   0.8s
# [15:00:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.598) r2: (test=0.629) total time=   0.8s
# [15:00:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.630) r2: (test=0.594) total time=   0.7s
# [15:00:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.598) r2: (test=0.606) total time=   0.8s
# [15:00:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.633) r2: (test=0.597) total time=   0.7s
# [15:00:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.620) r2: (test=0.619) total time=   1.7s
# [15:00:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.598) r2: (test=0.629) total time=   1.7s
# [15:00:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.630) r2: (test=0.594) total time=   1.7s
# [15:00:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.598) r2: (test=0.606) total time=   1.7s
# [15:00:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.633) r2: (test=0.597) total time=   1.7s
# [15:00:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.666) r2: (test=0.560) total time=   0.1s
# [15:00:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.674) r2: (test=0.529) total time=   0.1s
# [15:00:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.678) r2: (test=0.528) total time=   0.2s
# [15:00:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.696) r2: (test=0.466) total time=   0.1s
# [15:00:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.658) r2: (test=0.564) total time=   0.1s
# [15:00:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.688) r2: (test=0.531) total time=   0.3s
# [15:00:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.680) r2: (test=0.521) total time=   0.3s
# [15:00:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.692) r2: (test=0.510) total time=   0.3s
# [15:00:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.707) r2: (test=0.448) total time=   0.3s
# [15:00:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.687) r2: (test=0.524) total time=   0.3s
# [15:00:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.688) r2: (test=0.531) total time=   0.7s
# [15:00:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.680) r2: (test=0.521) total time=   0.6s
# [15:00:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.692) r2: (test=0.510) total time=   1.0s
# [15:00:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.707) r2: (test=0.448) total time=   1.1s
# [15:00:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.687) r2: (test=0.524) total time=   0.6s
# [15:00:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.774) r2: (test=0.406) total time=   0.3s
# [15:00:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.774) r2: (test=0.380) total time=   0.3s
# [15:00:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.780) r2: (test=0.377) total time=   0.3s
# [15:00:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.771) r2: (test=0.344) total time=   0.3s
# [15:00:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.792) r2: (test=0.368) total time=   0.2s
# [15:00:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.774) r2: (test=0.406) total time=   0.5s
# [15:00:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.774) r2: (test=0.380) total time=   0.5s
# [15:00:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.780) r2: (test=0.377) total time=   0.5s
# [15:00:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.771) r2: (test=0.344) total time=   0.5s
# [15:00:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.792) r2: (test=0.368) total time=   0.5s
# [15:00:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.774) r2: (test=0.406) total time=   1.1s
# [15:00:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.774) r2: (test=0.380) total time=   1.2s
# [15:00:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.780) r2: (test=0.377) total time=   1.1s
# [15:00:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.771) r2: (test=0.344) total time=   1.2s
# [15:00:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.792) r2: (test=0.368) total time=   1.1s
# [15:00:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.815) r2: (test=0.342) total time=   0.4s
# [15:00:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.792) r2: (test=0.350) total time=   0.4s
# [15:00:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.801) r2: (test=0.343) total time=   0.4s
# [15:01:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.781) r2: (test=0.326) total time=   0.4s
# [15:01:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.810) r2: (test=0.339) total time=   0.4s
# [15:01:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.815) r2: (test=0.342) total time=   0.7s
# [15:01:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.792) r2: (test=0.350) total time=   0.7s
# [15:01:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.801) r2: (test=0.343) total time=   0.7s
# [15:01:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.781) r2: (test=0.326) total time=   0.7s
# [15:01:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.810) r2: (test=0.339) total time=   0.7s
# [15:01:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.815) r2: (test=0.342) total time=   1.8s
# [15:01:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.792) r2: (test=0.350) total time=   1.6s
# [15:01:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.801) r2: (test=0.343) total time=   1.7s
# [15:01:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.781) r2: (test=0.326) total time=   1.6s
# [15:01:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.810) r2: (test=0.339) total time=   1.8s
# [15:01:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv=5, estimator=XGBRegressor(),
#              param_grid={'gamma': [0.01, 0.1],
#                          'learning_rate': [0.001, 0.01, 0.1, 1],
#                          'max_depth': [3, 6, 9],
#                          'n_estimators': [100, 200, 500]},
#              refit='r2', scoring=['r2', 'neg_root_mean_squared_error'],
#              verbose=4)

# %%
print(GS.best_params_)
# Out:
# {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}

# %%
print(GS.best_score_)
# Out:
# 0.6512526218803734

# %% [markdown]
# # Komparasi

# %%
def evaluate_model(model, x_test, y_test):

    from sklearn import metrics

    # Prediksi data uji 
    y_pred = model.predict(x_test)

    # Menghitung akurasi, presisi, recall, f1-score, dan kappa score
    acc = model.score(x_test,y_test)
    mae = metrics.mean_absolute_error(y_test, y_pred)
    mse = metrics.mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)  

    return {'acc': acc, 'mae': mae, 'mse': mse, 'rmse': rmse}

# %%
linear_eval = evaluate_model(lin_reg, x_test, y_test)
poly_eval = evaluate_model(lin_reg2, x_poly_test, y_test)
dt_eval = evaluate_model(r_dt, x_test, y_test)
rf_eval = evaluate_model(rf_reg, x_test, y_test)
xgboost_eval = evaluate_model(GS, x_test, y_test)


print('Accuracy:', linear_eval['acc'])
print('MAE:', linear_eval['mae'])
print('MSE:', linear_eval['mse'])
print('RMSE:', linear_eval['rmse'])
# Out:
# Accuracy: 0.709848376778935
# MAE: 0.43671122767869347
# MSE: 0.298568897362312
# RMSE: 0.5464145837752795

# %%
keys = linear_eval.keys()
values = zip(linear_eval.values(), poly_eval.values(), dt_eval.values(), rf_eval.values(), xgboost_eval.values())
dictionary = dict(zip(keys, values))

print(dictionary)
# Out:
# {'acc': (0.709848376778935, 0.7092352979379414, 0.29815969220453153, 0.6057548425255408, 0.6755886179014807), 'mae': (0.43671122767869347, 0.4378834104151186, 0.6781570856136532, 0.5059801675132595, 0.45993139681477896), 'mse': (0.298568897362312, 0.29919976156882433, 0.7222006359870177, 0.405682176273397, 0.33382252895804787), 'rmse': (0.5464145837752795, 0.5469915552993705, 0.8498238852768365, 0.6369318458621747, 0.5777737697040667)}

# %%
data = pd.DataFrame(dictionary, index=['Linear Regression','Polynomial Regression','Decision Tree','Random Forest','GridSearchCV'])
data
# Out:
#                             acc       mae       mse      rmse
# Linear Regression      0.709848  0.436711  0.298569  0.546415
# Polynomial Regression  0.709235  0.437883  0.299200  0.546992
# Decision Tree          0.298160  0.678157  0.722201  0.849824
# Random Forest          0.605755  0.505980  0.405682  0.636932
# GridSearchCV           0.675589  0.459931  0.333823  0.577774

# %%
# set width of bar
barWidth = 0.2
fig = plt.subplots(figsize =(10, 6))


# set height of bar
linear_score = [linear_eval['acc']]
poly_score= [poly_eval['acc']]
dt_score = [dt_eval['acc']]
rf_score = [rf_eval['acc']]

#Set position of bar on X axis
br1 = np.arange(len(linear_score))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]


# Make the plot
plt.bar(br1, linear_score, color ='red', width = barWidth ,
		edgecolor ='grey', label ='Liniear Regression')
plt.bar(br2, poly_score, color ='yellow', width =barWidth ,
		edgecolor ='grey', label ='Polynomial Regression')
plt.bar(br3, dt_score, color ='green', width =barWidth,
		edgecolor ='grey', label ='Decision Tree')
plt.bar(br4, rf_score, color ='cyan', width = barWidth,
		edgecolor ='grey', label ='Random Forest')


# Adding Xticks
plt.xlabel('Model', fontweight ='bold', fontsize = 15)
plt.ylabel('Metrics', fontweight ='bold', fontsize = 15)
plt.ylim(0,1)
plt.xticks([])

plt.legend()
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# 1. Model dengan akurasi terbaik adalah model dengan linear regression

# %% [markdown]
# # Deployment

# %%
import warnings
warnings.filterwarnings("ignore")

#Masukkan nilai (Avg. Area Income	Avg., Area Number of Rooms,	Avg. Area Number of Bedrooms,	Area Population,Price)
example = np.array([[70000, 3, 5, 23086, 1058987]])
age = lin_reg.predict(example)

print(f"Usia rumah yang tersedia {age[0]:.2f} Tahun ")
# Out:
# Usia rumah yang tersedia 7.57 Tahun

# %%
import pickle

with open('model_predict_home','wb') as file:
  pickle.dump(lin_reg,file)

# %%
with open('model_predict_home','rb') as file:
  myModel = pickle.load(file)

# %%
# testing

myModel.predict(example)
# Out:
# array([7.57368915])

# %% [markdown]
# # Simpan Model dengan Joblib

# %%
import joblib

# %%
joblib.dump((myModel, lin_reg), "model_predict_home_age.pkl")
# Out:
# ['model_predict_home_age.pkl']
